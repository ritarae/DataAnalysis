# %%
import pandas as pd
#安装panda包
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-1-7dd3504c366f> in <module>()
# ----> 1 import pandas as pd
#
# ImportError: No module named pandas

# %%
import pandas as pd
#降低numpy版本
# Out:
# c:\python27\lib\site-packages\pandas\_libs\__init__.py:4: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from .tslib import iNaT, NaT, Timestamp, Timedelta, OutOfBoundsDatetime
# c:\python27\lib\site-packages\pandas\__init__.py:26: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import (hashtable as _hashtable,
# c:\python27\lib\site-packages\pandas\core\dtypes\common.py:6: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import algos, lib
# c:\python27\lib\site-packages\pandas\core\util\hashing.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import hashing, tslib
# c:\python27\lib\site-packages\pandas\core\indexes\base.py:7: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import (lib, index as libindex, tslib as libts,
# c:\python27\lib\site-packages\pandas\tseries\offsets.py:21: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   import pandas._libs.tslibs.offsets as liboffsets
# c:\python27\lib\site-packages\pandas\core\ops.py:16: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import algos as libalgos, ops as libops
# c:\python27\lib\site-packages\pandas\core\indexes\interval.py:32: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs.interval import (
# c:\python27\lib\site-packages\pandas\core\internals.py:14: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import internals as libinternals
# c:\python27\lib\site-packages\pandas\core\sparse\array.py:33: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   import pandas._libs.sparse as splib
# c:\python27\lib\site-packages\pandas\core\window.py:36: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   import pandas._libs.window as _window
# c:\python27\lib\site-packages\pandas\core\groupby\groupby.py:68: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import (lib, reduction,
# c:\python27\lib\site-packages\pandas\core\reshape\reshape.py:30: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import algos as _algos, reshape as _reshape
# c:\python27\lib\site-packages\pandas\io\parsers.py:45: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   import pandas._libs.parsers as parsers
# c:\python27\lib\site-packages\pandas\io\pytables.py:50: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected zd, got zd
#   from pandas._libs import algos, lib, writers as libwriters

# %%
import pandas as pd

# %%
ratings=pd.read_csv("C:\data\datasets\movielens\ml-20m\ratings.csv",header=0)
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-d37f255501ae> in <module>()
# ----> 1 ratings=pd.read_csv("C:\data\datasets\movielens\ml-20m\ratings.csv",header=0)
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# atings.csv does not exist

# %%
ratings=pd.read_csv('C:\data\datasets\movielens\ml-20m\ratings.csv',header=0)
#重新import
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-f1be808b963f> in <module>()
# ----> 1 ratings=pd.read_csv('C:\data\datasets\movielens\ml-20m\ratings.csv',header=0)
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
ratings=pd.read_csv('C:\data\datasets\movielens\ml-20m\ratings.csv',header=0)
#改成绝对路径 / or \\
# Out:
# ---------------------------------------------------------------------------
# IOError                                   Traceback (most recent call last)
# <ipython-input-3-f1be808b963f> in <module>()
# ----> 1 ratings=pd.read_csv('C:\data\datasets\movielens\ml-20m\ratings.csv',header=0)
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# --> 678         return _read(filepath_or_buffer, kwds)
#     679
#     680     parser_f.__name__ = name
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in _read(filepath_or_buffer, kwds)
#     438
#     439     # Create the parser.
# --> 440     parser = TextFileReader(filepath_or_buffer, **kwds)
#     441
#     442     if chunksize or iterator:
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in __init__(self, f, engine, **kwds)
#     785             self.options['has_index_names'] = kwds['has_index_names']
#     786
# --> 787         self._make_engine(self.engine)
#     788
#     789     def close(self):
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in _make_engine(self, engine)
#    1012     def _make_engine(self, engine='c'):
#    1013         if engine == 'c':
# -> 1014             self._engine = CParserWrapper(self.f, **self.options)
#    1015         else:
#    1016             if engine == 'python':
#
# c:\python27\lib\site-packages\pandas\io\parsers.pyc in __init__(self, src, **kwds)
#    1706         kwds['usecols'] = self.usecols
#    1707
# -> 1708         self._reader = parsers.TextReader(src, **kwds)
#    1709
#    1710         passed_names = self.names is None
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# atings.csv does not exist

# %%
ratings=pd.read_csv('C:\\data\\datasets\\movielens\\ml-20m\\ratings.csv',header=0)
#载入文件

# %%
ratings[0:5]
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
movies=pd.read_csv('C:\\data\\datasets\\movielens\\ml-20m\\movies.csv',header=0)

# %%
movies[0:5]
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
data=ratings.merge(movies,on='movieId')
#文件合并

# %%
data[:5]
# Out:
#    userId  movieId  rating   timestamp           title  \
# 0       1        2     3.5  1112486027  Jumanji (1995)
# 1       5        2     3.0   851527569  Jumanji (1995)
# 2      13        2     3.0   849082742  Jumanji (1995)
# 3      29        2     3.0   835562174  Jumanji (1995)
# 4      34        2     3.0   846509384  Jumanji (1995)
#
#                        genres
# 0  Adventure|Children|Fantasy
# 1  Adventure|Children|Fantasy
# 2  Adventure|Children|Fantasy
# 3  Adventure|Children|Fantasy
# 4  Adventure|Children|Fantasy

# %%
rating_by_title=data.groupby('title').size()
#汇总评论数

# %%
#降序排列
rating_by_title.order(ascending=False)[:10]
#没有order属性,用sort_value方法
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-084381ada5f4> in <module>()
#       1 #降序排列
# ----> 2 rating_by_title.order(ascending=False)[:10]
#       3 #没有order属性,用sort_value方法
#
# c:\python27\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'order'

# %%
rating_by_title.sort_values(ascending=False)[:10]
# Out:
# title
# Pulp Fiction (1994)                          67310
# Forrest Gump (1994)                          66172
# Shawshank Redemption, The (1994)             63366
# Silence of the Lambs, The (1991)             63299
# Jurassic Park (1993)                         59715
# Star Wars: Episode IV - A New Hope (1977)    54502
# Braveheart (1995)                            53769
# Terminator 2: Judgment Day (1991)            52244
# Matrix, The (1999)                           51334
# Schindler's List (1993)                      50054
# dtype: int64

# %%
#筛选一万以上的评论
active_title=rating_by_title.index[rating_by_title>=10000]

# %%
active_titlesort_values
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-5b453d4c95c4> in <module>()
# ----> 1 active_titlesort_values
#
# NameError: name 'active_titlesort_values' is not defined

# %%
#得出这部分影片的平均分
mean_ratings=data.pivot('rating','title',aggfunc='mean')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-15-10095d8ffdec> in <module>()
#       1 #得出这部分影片的平均分
# ----> 2 mean_ratings=data.pivot('rating','title',aggfunc='mean')
#
# TypeError: pivot() got an unexpected keyword argument 'aggfunc'

# %%
mean_ratings=data.pivot_table('rating','title',aggfunc='mean')

# %%
mean_ratings=mean_ratings.ix[active_title]
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
mean_ratings
# Out:
#                                                       rating
# title
# 10 Things I Hate About You (1999)                   3.473909
# 12 Angry Men (1957)                                 4.224138
# 2001: A Space Odyssey (1968)                        3.955748
# 28 Days Later (2002)                                3.752424
# 300 (2007)                                          3.672342
# A.I. Artificial Intelligence (2001)                 3.214050
# Abyss, The (1989)                                   3.658099
# Ace Ventura: Pet Detective (1994)                   2.982342
# Ace Ventura: When Nature Calls (1995)               2.607412
# Addams Family Values (1993)                         2.992078
# Adventures of Priscilla, Queen of the Desert, T...  3.649583
# African Queen, The (1951)                           4.101558
# Air Force One (1997)                                3.306726
# Airplane! (1980)                                    3.798261
# Aladdin (1992)                                      3.680829
# Alien (1979)                                        4.041784
# Alien: Resurrection (1997)                          3.008599
# Aliens (1986)                                       4.005642
# Alien³ (a.k.a. Alien 3) (1992)                      3.093127
# Almost Famous (2000)                                3.855403
# Amadeus (1984)                                      4.073887
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...  4.197072
# American Beauty (1999)                              4.155934
# American History X (1998)                           4.151208
# American Pie (1999)                                 3.331509
# American President, The (1995)                      3.667713
# Animal House (1978)                                 3.825108
# Annie Hall (1977)                                   4.081259
# Antz (1998)                                         3.303208
# Apocalypse Now (1979)                               4.108900
# ...                                                      ...
# Truth About Cats & Dogs, The (1996)                 3.405032
# Twelve Monkeys (a.k.a. 12 Monkeys) (1995)           3.898055
# Twister (1996)                                      3.196249
# Unbreakable (2000)                                  3.481852
# Unforgiven (1992)                                   3.988340
# Untouchables, The (1987)                            3.884503
# Usual Suspects, The (1995)                          4.334372
# V for Vendetta (2006)                               3.927417
# Vertigo (1958)                                      4.148006
# WALL·E (2008)                                       4.038929
# Wag the Dog (1997)                                  3.514706
# Wallace & Gromit: A Close Shave (1995)              4.167315
# Wallace & Gromit: The Wrong Trousers (1993)         4.181068
# Waterworld (1995)                                   2.852097
# Wayne's World (1992)                                3.460988
# Wedding Singer, The (1998)                          3.410378
# What's Eating Gilbert Grape (1993)                  3.755830
# When Harry Met Sally... (1989)                      3.842996
# While You Were Sleeping (1995)                      3.500345
# Who Framed Roger Rabbit? (1988)                     3.529693
# Wild Wild West (1999)                               2.292716
# William Shakespeare's Romeo + Juliet (1996)         3.583816
# Willy Wonka & the Chocolate Factory (1971)          3.709935
# Witness (1985)                                      3.849292
# Wizard of Oz, The (1939)                            3.981681
# X-Files: Fight the Future, The (1998)               3.328451
# X-Men (2000)                                        3.599009
# X2: X-Men United (2003)                             3.681243
# You've Got Mail (1998)                              3.144028
# Young Frankenstein (1974)                           3.996785
#
# [462 rows x 1 columns]

# %%
mean_ratings.sort_values(by=['rating'],ascending=False)
# Out:
#                                                       rating
# title
# Shawshank Redemption, The (1994)                    4.446990
# Godfather, The (1972)                               4.364732
# Usual Suspects, The (1995)                          4.334372
# Schindler's List (1993)                             4.310175
# Godfather: Part II, The (1974)                      4.275641
# Seven Samurai (Shichinin no samurai) (1954)         4.274180
# Rear Window (1954)                                  4.271334
# Casablanca (1942)                                   4.258327
# One Flew Over the Cuckoo's Nest (1975)              4.248079
# Dr. Strangelove or: How I Learned to Stop Worry...  4.247287
# City of God (Cidade de Deus) (2002)                 4.235410
# North by Northwest (1959)                           4.233538
# Fight Club (1999)                                   4.227123
# 12 Angry Men (1957)                                 4.224138
# Dark Knight, The (2008)                             4.220129
# Raiders of the Lost Ark (Indiana Jones and the ...  4.219009
# Spirited Away (Sen to Chihiro no kamikakushi) (...  4.203810
# Chinatown (1974)                                    4.199673
# Amelie (Fabuleux destin d'Amélie Poulain, Le) (...  4.197072
# Star Wars: Episode IV - A New Hope (1977)           4.190672
# To Kill a Mockingbird (1962)                        4.188943
# Star Wars: Episode V - The Empire Strikes Back ...  4.188202
# Maltese Falcon, The (1941)                          4.187212
# Matrix, The (1999)                                  4.187186
# Goodfellas (1990)                                   4.183633
# Wallace & Gromit: The Wrong Trousers (1993)         4.181068
# Memento (2000)                                      4.178547
# Silence of the Lambs, The (1991)                    4.177057
# Princess Bride, The (1987)                          4.176732
# Life Is Beautiful (La Vita è bella) (1997)          4.175837
# ...                                                      ...
# Mission: Impossible II (2000)                       2.961368
# Armageddon (1998)                                   2.957471
# Naked Gun 33 1/3: The Final Insult (1994)           2.955508
# Deep Impact (1998)                                  2.953132
# Lost World: Jurassic Park, The (1997)               2.952822
# Dumb & Dumber (Dumb and Dumber) (1994)              2.952470
# Pocahontas (1995)                                   2.946114
# Casper (1995)                                       2.932000
# Hot Shots! Part Deux (1993)                         2.914503
# Specialist, The (1994)                              2.902051
# Batman Forever (1995)                               2.894727
# Nine Months (1995)                                  2.891731
# Blair Witch Project, The (1999)                     2.884072
# Nutty Professor, The (1996)                         2.882707
# Waterworld (1995)                                   2.852097
# Species (1995)                                      2.850271
# Charlie's Angels (2000)                             2.807285
# Arachnophobia (1990)                                2.787105
# Last Action Hero (1993)                             2.778743
# Beverly Hills Cop III (1994)                        2.749866
# City Slickers II: The Legend of Curly's Gold (1...  2.735471
# Johnny Mnemonic (1995)                              2.732607
# Cable Guy, The (1996)                               2.702761
# Honey, I Shrunk the Kids (1989)                     2.702726
# Mortal Kombat (1995)                                2.653875
# Ace Ventura: When Nature Calls (1995)               2.607412
# Congo (1995)                                        2.604744
# Coneheads (1993)                                    2.593559
# Judge Dredd (1995)                                  2.538285
# Wild Wild West (1999)                               2.292716
#
# [462 rows x 1 columns]

# %%
rating_std_by_title=data.groupby('title')['rating'].std()

# %%
rating_std_by_title=rating_std_by_title.ix[active_title]
# Out:
# c:\python27\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
#评论数与评分差距较大的电影
rating_std_by_title.sort_values(ascending=False)
# Out:
# title
# Blair Witch Project, The (1999)                                                   1.239533
# Rocky Horror Picture Show, The (1975)                                             1.212654
# Dumb & Dumber (Dumb and Dumber) (1994)                                            1.193118
# Natural Born Killers (1994)                                                       1.192219
# Moulin Rouge (2001)                                                               1.158249
# Titanic (1997)                                                                    1.156372
# Eyes Wide Shut (1999)                                                             1.155927
# Ace Ventura: When Nature Calls (1995)                                             1.151479
# English Patient, The (1996)                                                       1.145200
# Star Wars: Episode I - The Phantom Menace (1999)                                  1.140808
# Armageddon (1998)                                                                 1.140092
# Dirty Dancing (1987)                                                              1.129810
# Mortal Kombat (1995)                                                              1.122321
# Grease (1978)                                                                     1.117452
# Starship Troopers (1997)                                                          1.116563
# South Park: Bigger, Longer and Uncut (1999)                                       1.113746
# American Pie (1999)                                                               1.110543
# Ace Ventura: Pet Detective (1994)                                                 1.106229
# Star Wars: Episode II - Attack of the Clones (2002)                               1.105426
# First Knight (1995)                                                               1.101227
# Matrix Revolutions, The (2003)                                                    1.096662
# Mars Attacks! (1996)                                                              1.094957
# Babe (1995)                                                                       1.091497
# Austin Powers: The Spy Who Shagged Me (1999)                                      1.082517
# Gone with the Wind (1939)                                                         1.080742
# You've Got Mail (1998)                                                            1.079725
# Sound of Music, The (1965)                                                        1.078197
# Nutty Professor, The (1996)                                                       1.075171
# Star Trek VI: The Undiscovered Country (1991)                                     1.072894
# Scream (1996)                                                                     1.070594
#                                                                                     ...
# Casino Royale (2006)                                                              0.791573
# Full Metal Jacket (1987)                                                          0.790180
# Raiders of the Lost Ark (Indiana Jones and the Raiders of the Lost Ark) (1981)    0.784264
# Iron Man (2008)                                                                   0.783552
# Batman Begins (2005)                                                              0.779839
# Rain Man (1988)                                                                   0.779666
# Witness (1985)                                                                    0.778944
# 12 Angry Men (1957)                                                               0.775291
# Fugitive, The (1993)                                                              0.772525
# Memento (2000)                                                                    0.771272
# Pianist, The (2002)                                                               0.769115
# One Flew Over the Cuckoo's Nest (1975)                                            0.768709
# Untouchables, The (1987)                                                          0.768644
# Bourne Supremacy, The (2004)                                                      0.764789
# Bourne Ultimatum, The (2007)                                                      0.763016
# Sting, The (1973)                                                                 0.761936
# City of God (Cidade de Deus) (2002)                                               0.759312
# Bourne Identity, The (2002)                                                       0.758436
# Stand by Me (1986)                                                                0.758232
# Donnie Brasco (1997)                                                              0.757412
# Usual Suspects, The (1995)                                                        0.756783
# Rear Window (1954)                                                                0.752636
# North by Northwest (1959)                                                         0.752293
# American History X (1998)                                                         0.750459
# In the Line of Fire (1993)                                                        0.747990
# Great Escape, The (1963)                                                          0.737883
# Prestige, The (2006)                                                              0.728842
# Departed, The (2006)                                                              0.727475
# Shawshank Redemption, The (1994)                                                  0.717525
# Catch Me If You Can (2002)                                                        0.716596
# Name: rating, Length: 462, dtype: float64
